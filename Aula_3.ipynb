# %% [markdown]
# # INTELIGÊNCIA COMPUTACIONAL

# %% [markdown]
# ## Aula 3 - Seaborn

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
data = pd.read_csv('iris.csv')

# %%
plt.plot(data.sepallength, data.sepalwidth, ls='', marker='o', label='sepal')
plt.plot(data.petallength, data.petalwidth, ls='', marker='o', label='petal')

# %%
data.columns

# %%
plt.hist(data.sepallength, bins=25)
# Out:
# (array([ 4.,  1.,  6.,  5., 16.,  9.,  5.,  6.,  7., 14.,  7.,  9.,  6.,
#         13.,  7.,  7.,  8.,  3.,  5.,  1.,  4.,  1.,  1.,  4.,  1.]),
#  array([4.3  , 4.444, 4.588, 4.732, 4.876, 5.02 , 5.164, 5.308, 5.452,
#         5.596, 5.74 , 5.884, 6.028, 6.172, 6.316, 6.46 , 6.604, 6.748,
#         6.892, 7.036, 7.18 , 7.324, 7.468, 7.612, 7.756, 7.9  ]),
#  <a list of 25 Patch objects>)

# %%
(data.groupby('class').mean().plot(color=['red','blue','black','green'], fontsize=10.0, figsize=(4,4)))

# %%
import seaborn as sns

# %%
sns.jointplot(x='sepallength',y='sepalwidth', data=data, height=4)

# %%
# %config IPCompleter.greedy=True

# %%
sns.pairplot(data, hue='class', size=3)
# Out:
# C:\Users\Rafael\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
